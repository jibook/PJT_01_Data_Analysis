# %% [markdown]
# # 제주도 인구 데이터 전처리

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
jj_j = pd.read_csv('./data/제주시_0.csv', sep=',')
jj_j
# Out:
#     연령별(1)      제주시     한림읍     애월읍     구좌읍     조천읍    한경면    추자면    우도면  \
# 0       총계  492,466  21,249  36,913  15,546  25,339  9,029  1,677  1,740
# 1     0~4세   19,099     592   1,346     354     822    208     24     42
# 2     5~9세   26,625     924   2,081     579   1,329    302     39     40
# 3   10~14세   26,518     891   1,936     550   1,126    293     48     43
# 4   15~19세   26,756     876   1,506     581   1,097    275     40     56
# 5   20~24세   31,765   1,057   1,801     667   1,378    368     62     64
# 6   25~29세   31,831   1,005   1,881     712   1,398    366     49     97
# 7   30~34세   26,860     873   1,754     627   1,259    300     47     93
# 8   35~39세   35,826   1,269   2,658     982   1,770    513     67     90
# 9   40~44세   38,692   1,573   3,165   1,071   1,983    644     86    125
# 10  45~49세   44,220   1,925   3,383   1,252   2,143    745    107    135
# 11  50~54세   42,818   1,957   3,279   1,434   2,237    796    134    178
# ...

# %%
jj_s = pd.read_excel('./data/서귀포시.xlsx')
jj_s
# Out:
#     연령별(1)    서귀포시    대정읍    남원읍    성산읍    안덕면    표선면   송산동   정방동   중앙동   천지동  \
# 0        계  182169  21761  18766  15412  11982  12325  4171  2196  3519  3524
# 1     0~4세    5919    599    456    359    349    301    81    46    71    79
# 2     5~9세    8654   1255    680    516    509    516   152    67   105    81
# 3   10~14세    8974   1306    737    556    508    507   158    68   102   107
# 4   15~19세    8413   1187    804    512    472    430   179    68   144   144
# 5   20~24세    9731    972   1057    704    623    633   224    85   174   172
# 6   25~29세    9419    858    905    734    740    597   216    84   177   175
# 7   30~34세    8185    762    703    621    546    453   155    85   113   154
# 8   35~39세   11684   1290    929    841    739    650   216   130   165   223
# 9   40~44세   13491   1755   1167    941    910    856   271   153   224   216
# 10  45~49세   15973   2189   1581   1200    994   1081   339   176   237   325
# ...

# %% [markdown]
# ### 제주시와 서귀포시만 나타내기 및 전처리

# %%
var_list = ['연령별(1)', '제주시']
data_j = jj_j[var_list]
data_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연령별(1)  19 non-null     object
#  1   제주시     19 non-null     object
# dtypes: object(2)
# memory usage: 432.0+ bytes

# %% [markdown]
# #### 제주시 인구에서 ,를 빼고 object에서 int로 바꾸기

# %%
data_j['제주시'] = data_j['제주시'].str.replace(',','').astype(int)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_26780/1473413911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['제주시'] = data_j['제주시'].str.replace(',','').astype(int)

# %%
data_j['제주시'] = data_j['제주시'].astype(np.int64)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_26780/1074963162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['제주시'] = data_j['제주시'].astype(np.int64)

# %%
data_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연령별(1)  19 non-null     object
#  1   제주시     19 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 432.0+ bytes

# %%
data_j['연령별(1)'] = data_j['연령별(1)'].str.replace('총계','계')
data_j
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_26780/2163027892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['연령별(1)'] = data_j['연령별(1)'].str.replace('총계','계')
#     연령별(1)     제주시
# 0        계  492466
# 1     0~4세   19099
# 2     5~9세   26625
# 3   10~14세   26518
# 4   15~19세   26756
# 5   20~24세   31765
# 6   25~29세   31831
# 7   30~34세   26860
# 8   35~39세   35826
# 9   40~44세   38692
# 10  45~49세   44220
# 11  50~54세   42818
# 12  55~59세   37935
# 13  60~64세   32801
# 14  65~69세   22077
# 15  70~74세   16937
# 16  75~79세   13153
# 17  80~84세    9830
# 18  85~89세    5747

# %%
var_list = ['연령별(1)', '서귀포시']
data_s = jj_s[var_list]
data_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연령별(1)  19 non-null     object
#  1   서귀포시    19 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 432.0+ bytes

# %% [markdown]
# ## 제주시 서귀포시 합치기

# %%
data_jj = pd.merge(data_j, data_s, how='inner', on = '연령별(1)')
data_jj
# Out:
#     연령별(1)     제주시    서귀포시
# 0        계  492466  182169
# 1     0~4세   19099    5919
# 2     5~9세   26625    8654
# 3   10~14세   26518    8974
# 4   15~19세   26756    8413
# 5   20~24세   31765    9731
# 6   25~29세   31831    9419
# 7   30~34세   26860    8185
# 8   35~39세   35826   11684
# 9   40~44세   38692   13491
# 10  45~49세   44220   15973
# 11  50~54세   42818   16218
# 12  55~59세   37935   15430
# 13  60~64세   32801   14644
# 14  65~69세   22077   10239
# 15  70~74세   16937    8515
# 16  75~79세   13153    6986
# 17  80~84세    9830    5187
# 18  85~89세    5747    3128

# %%
pd.concat([data_j, data_s], axis=1)
# Out:
#     연령별(1)     제주시  연령별(1)    서귀포시
# 0        계  492466       계  182169
# 1     0~4세   19099    0~4세    5919
# 2     5~9세   26625    5~9세    8654
# 3   10~14세   26518  10~14세    8974
# 4   15~19세   26756  15~19세    8413
# 5   20~24세   31765  20~24세    9731
# 6   25~29세   31831  25~29세    9419
# 7   30~34세   26860  30~34세    8185
# 8   35~39세   35826  35~39세   11684
# 9   40~44세   38692  40~44세   13491
# 10  45~49세   44220  45~49세   15973
# 11  50~54세   42818  50~54세   16218
# 12  55~59세   37935  55~59세   15430
# 13  60~64세   32801  60~64세   14644
# 14  65~69세   22077  65~69세   10239
# 15  70~74세   16937  70~74세    8515
# 16  75~79세   13153  75~79세    6986
# 17  80~84세    9830  80~84세    5187
# 18  85~89세    5747  85~89세    3128

# %%
pd.concat([data_j, data_s],  ignore_index=True)
# Out:
#     연령별(1)       제주시      서귀포시
# 0        계  492466.0       NaN
# 1     0~4세   19099.0       NaN
# 2     5~9세   26625.0       NaN
# 3   10~14세   26518.0       NaN
# 4   15~19세   26756.0       NaN
# 5   20~24세   31765.0       NaN
# 6   25~29세   31831.0       NaN
# 7   30~34세   26860.0       NaN
# 8   35~39세   35826.0       NaN
# 9   40~44세   38692.0       NaN
# 10  45~49세   44220.0       NaN
# 11  50~54세   42818.0       NaN
# 12  55~59세   37935.0       NaN
# 13  60~64세   32801.0       NaN
# 14  65~69세   22077.0       NaN
# 15  70~74세   16937.0       NaN
# 16  75~79세   13153.0       NaN
# 17  80~84세    9830.0       NaN
# 18  85~89세    5747.0       NaN
# 19       계       NaN  182169.0
# 20    0~4세       NaN    5919.0
# 21    5~9세       NaN    8654.0
# 22  10~14세       NaN    8974.0
# 23  15~19세       NaN    8413.0
# 24  20~24세       NaN    9731.0
# 25  25~29세       NaN    9419.0
# 26  30~34세       NaN    8185.0
# 27  35~39세       NaN   11684.0
# 28  40~44세       NaN   13491.0
# ...

# %%
data_jj.sort_values(['서귀포시'])
# Out:
#     연령별(1)     제주시    서귀포시
# 18  85~89세    5747    3128
# 17  80~84세    9830    5187
# 1     0~4세   19099    5919
# 16  75~79세   13153    6986
# 7   30~34세   26860    8185
# 4   15~19세   26756    8413
# 15  70~74세   16937    8515
# 2     5~9세   26625    8654
# 3   10~14세   26518    8974
# 6   25~29세   31831    9419
# 5   20~24세   31765    9731
# 14  65~69세   22077   10239
# 8   35~39세   35826   11684
# 9   40~44세   38692   13491
# 13  60~64세   32801   14644
# 12  55~59세   37935   15430
# 10  45~49세   44220   15973
# 11  50~54세   42818   16218
# 0        계  492466  182169

# %%
data_jj.sort_values(['제주시'])
# Out:
#     연령별(1)     제주시    서귀포시
# 18  85~89세    5747    3128
# 17  80~84세    9830    5187
# 16  75~79세   13153    6986
# 15  70~74세   16937    8515
# 1     0~4세   19099    5919
# 14  65~69세   22077   10239
# 3   10~14세   26518    8974
# 2     5~9세   26625    8654
# 4   15~19세   26756    8413
# 7   30~34세   26860    8185
# 5   20~24세   31765    9731
# 6   25~29세   31831    9419
# 13  60~64세   32801   14644
# 8   35~39세   35826   11684
# 12  55~59세   37935   15430
# 9   40~44세   38692   13491
# 11  50~54세   42818   16218
# 10  45~49세   44220   15973
# 0        계  492466  182169

# %% [markdown]
# # 제주도 진료 데이터 확인하기

# %%
df1 = pd.read_csv('./data/H_data/T20_2019_1백만.1.csv', encoding='cp949')
df2 = pd.read_csv('./data/H_data/T20_2019_1백만.2.csv', encoding='cp949')
df3 = pd.read_csv('./data/H_data/T20_2019_1백만.3.csv', encoding='cp949')
df4 = pd.read_csv('./data/H_data/HP_T20_2020_1.CSV', encoding='cp949')
df5 = pd.read_csv('./data/H_data/HP_T20_2020_2.CSV', encoding='cp949')
df6 = pd.read_csv('./data/H_data/HP_T20_2020_3.CSV', encoding='cp949')

# %%
data = pd.concat([df1,df2,df3,df4,df5,df6], ignore_index=True)

# %%
var_list = ['성별코드', '연령대코드', '시도코드', '진료과목코드', '주상병코드']
data_1920 = data[var_list]
data_1920.head()
# Out:
#    성별코드  연령대코드  시도코드  진료과목코드  주상병코드
# 0     2     12    46       5   M751
# 1     2     12    46       1  E1164
# 2     2     12    46       1   N308
# 3     2     12    46       1  E1164
# 4     2     12    46      13  H6531

# %%
condition1 = data_1920['시도코드'] == 49
data_jj = data_1920[condition1]
data_jj.head()
# Out:
#      성별코드  연령대코드  시도코드  진료과목코드  주상병코드
# 145     2     15    49       1   I109
# 146     2     15    49      10  M8100
# 147     2     15    49       1   J069
# 148     2     15    49      14   L509
# 149     2     15    49       1   T673

# %%
data_jj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341519 entries, 145 to 24905444
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   성별코드    341519 non-null  int64
#  1   연령대코드   341519 non-null  int64
#  2   시도코드    341519 non-null  int64
#  3   진료과목코드  341519 non-null  int64
#  4   주상병코드   341519 non-null  object
# dtypes: int64(4), object(1)
# memory usage: 15.6+ MB

# %%
from collections import Counter

for i in range(1, 19):
    agag = data_jj['연령대코드'] == i
    aggs = data_jj[agag]
    aggs_to = Counter(aggs['주상병코드'])
    
    print('연령대코드', i, '상위 30개 질병')
    print(aggs_to.most_common(30))
    print( )
    print('-------------------------------')
    print( )
# Out:
# 연령대코드 1 상위 30개 질병
# [('J209', 5906), ('J304', 960), ('J219', 788), ('J00', 781), ('H6500', 757), ('J0390', 659), ('J303', 625), ('J0190', 588), ('J069', 506), ('J029', 477), ('H6690', 357), ('J040', 352), ('J399', 292), ('H66000', 281), ('J22', 272), ('B_', 246), ('J189', 246), ('J0101', 238), ('J0191', 232), ('A090', 231), ('H6641', 219), ('J_', 219), ('R509', 196), ('J060', 195), ('A099', 185), ('J180', 166), ('Q_', 159), ('J320', 155), ('K529', 149), ('J4509', 147)]
#
# -------------------------------
#
# 연령대코드 2 상위 30개 질병
# [('J209', 3155), ('J304', 850), ('J303', 584), ('H6500', 530), ('J00', 500), ('J0190', 365), ('J0390', 363), ('J029', 331), ('J219', 330), ('J0100', 322), ('J_', 287), ('J040', 269), ('J399', 266), ('J329', 260), ('H101', 228), ('A090', 193), ('J0101', 166), ('A099', 145), ('R509', 141), ('R620', 136), ('J069', 134), ('J060', 128), ('H521', 126), ('H66001', 110), ('J042', 107), ('J189', 107), ('J180', 102), ('G808', 102), ('F_', 96), ('J36', 90)]
#
# ...

# %%
from collections import Counter

jj_list = []

for i in range(1, 19):
    agag = data_jj['연령대코드'] == i
    aggs = data_jj[agag]
    aggs_to = Counter(aggs['주상병코드'])
    
    jj_list.append(aggs_to.most_common(30))
    
    print(jj_list)
# Out:
# [[('J209', 5906), ('J304', 960), ('J219', 788), ('J00', 781), ('H6500', 757), ('J0390', 659), ('J303', 625), ('J0190', 588), ('J069', 506), ('J029', 477), ('H6690', 357), ('J040', 352), ('J399', 292), ('H66000', 281), ('J22', 272), ('B_', 246), ('J189', 246), ('J0101', 238), ('J0191', 232), ('A090', 231), ('H6641', 219), ('J_', 219), ('R509', 196), ('J060', 195), ('A099', 185), ('J180', 166), ('Q_', 159), ('J320', 155), ('K529', 149), ('J4509', 147)]]
# ...

# %%
data_jj['주상병코드'].unique()
# Out:
# array(['I109', 'M8100', 'J069', ..., 'K870', 'G820', 'P282'], dtype=object)

# %% [markdown]
# # 병원 데이터 시각화

# %%
hos_open = pd.read_excel('./data/hos_open.xlsx')
hos_open.head()
# Out:
#    영업상태명                                            도로명전체주소  \
# 0  영업/정상   대전광역시 대덕구 동서대로1777번길 2-0, 대전웰니스병원층 (송촌동,대전웰니스병원)
# 1  영업/정상  경상북도 경산시 경산로 174-0, A동 양지요양병원1~3층층 (옥산동,양지요양병원...
# 2  영업/정상                      전라남도 목포시 수강로12번길 11-1 (행복동2가)
# 3  영업/정상                     전라남도 목포시 녹색로 41,  (석현동)층 (석현동)
# 4  영업/정상           경상북도 영주시 반지미로 275-17, 새희망병원층 (가흥동,새희망병원)
#
#                 사업장명        좌표정보(x)        좌표정보(y) 의료기관종별명   진료과목내용  진료과목내용명
# 0            대전웰니스병원  239729.320277  317207.703078      의사      NaN      NaN
# 1  의료법인양지의료재단 양지기쁨병원  356018.202591  259569.888640     NaN      NaN      NaN
# 2  의료법인항운의료재단 목포노동병원  143735.241189  143322.546469      의사   내과, 외과   내과, 외과
# 3             목포미래병원  147497.000000  147318.000000      의사      NaN      NaN
# 4    의료법인태훈의료재단새희망병원  342313.000000  370443.000000     NaN  정신건강의학과  정신건강의학과

# %%
hos_open['도로명전체주소'].str.split(' ').str[0].str[0] == '제주특별자치도'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4625    False
# 4626    False
# 4627    False
# 4628    False
# 4629    False
# Name: 도로명전체주소, Length: 4630, dtype: bool

# %%
condition = hos_open['도로명전체주소'].str.split(' ').str[0] == '제주특별자치도'
hos_jj = hos_open[condition]
hos_jj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 475 to 3980
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   영업상태명    29 non-null     object
#  1   도로명전체주소  29 non-null     object
#  2   사업장명     29 non-null     object
#  3   좌표정보(x)  29 non-null     float64
#  4   좌표정보(y)  29 non-null     float64
#  5   의료기관종별명  29 non-null     object
#  6   진료과목내용   29 non-null     object
#  7   진료과목내용명  29 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 2.0+ KB

# %%
hos_jj.to_excel('./data/hos_jj.xlsx', index = False)

# %%
adress_01 = hos_jj['도로명전체주소'].str.split(',').str[0]
adress_01
# Out:
# 475         제주특별자치도 제주시 산천단남길 10 (아라일동)
# 476        제주특별자치도 서귀포시 일주동로 8638 (동홍동)
# 477           제주특별자치도 제주시 탑동로 26 (삼도이동)
# 478          제주특별자치도 제주시 중앙로 373 (이도이동)
# 675          제주특별자치도 제주시 서광로 222 (삼도일동)
# 1731            제주특별자치도 제주시 한림읍 한수풀로 58
# 1732         제주특별자치도 제주시 중앙로 373 (이도이동)
# 1733          제주특별자치도 제주시 월랑로 91 (이호이동)
# 2179    제주특별자치도 서귀포시 1100로 453-95 (회수동)
# 2180          제주특별자치도 서귀포시 장수로 47 (동홍동)
# 2181       제주특별자치도 서귀포시 일주동로 8638 (동홍동)
# 2182          제주특별자치도 제주시 동광로 42 (이도이동)
# 2183            제주특별자치도 제주시 조천읍 신조로 203
# 2184            제주특별자치도 제주시 연삼로 16 (연동)
# 2185                제주특별자치도 제주시 서광로 301
# 2186         제주특별자치도 제주시 산천단남길 10 (아라일동
# 2187         제주특별자치도 제주시 한북로 309 (아라일동)
# 2188                제주특별자치도 제주시 중앙로 616
# 2189          제주특별자치도 제주시 연신로 52 (이도이동)
# 2190               제주특별자치도 제주시 산천단남길 10
# 2191           제주특별자치도 제주시 죽성서길 6 (오등동)
# 2192           제주특별자치도 제주시 탑동로 26 (삼도이동
# 2193          제주특별자치도 제주시 관덕로 30 (삼도이동)
# ...

# %%
adress_01.str.split('(').str[0]
# Out:
# 475          제주특별자치도 제주시 산천단남길 10
# 476        제주특별자치도 서귀포시 일주동로 8638
# 477            제주특별자치도 제주시 탑동로 26
# 478           제주특별자치도 제주시 중앙로 373
# 675           제주특별자치도 제주시 서광로 222
# 1731       제주특별자치도 제주시 한림읍 한수풀로 58
# 1732          제주특별자치도 제주시 중앙로 373
# 1733           제주특별자치도 제주시 월랑로 91
# 2179    제주특별자치도 서귀포시 1100로 453-95
# 2180          제주특별자치도 서귀포시 장수로 47
# 2181       제주특별자치도 서귀포시 일주동로 8638
# 2182           제주특별자치도 제주시 동광로 42
# 2183       제주특별자치도 제주시 조천읍 신조로 203
# 2184           제주특별자치도 제주시 연삼로 16
# 2185           제주특별자치도 제주시 서광로 301
# 2186         제주특별자치도 제주시 산천단남길 10
# 2187          제주특별자치도 제주시 한북로 309
# 2188           제주특별자치도 제주시 중앙로 616
# 2189           제주특별자치도 제주시 연신로 52
# 2190          제주특별자치도 제주시 산천단남길 10
# 2191           제주특별자치도 제주시 죽성서길 6
# 2192           제주특별자치도 제주시 탑동로 26
# 2193           제주특별자치도 제주시 관덕로 30
# 2194            제주특별자치도 제주시 동광로 96
# 2195          제주특별자치도 제주시 서광로 193
# 2196           제주특별자치도 제주시 도령로 65
# 2197         제주특별자치도 제주시 아란13길 15
# ...

# %%
hos_jj['주소'] = adress_01.str.split('(').str[0]
hos_jj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 475 to 3980
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   영업상태명    29 non-null     object
#  1   도로명전체주소  29 non-null     object
#  2   사업장명     29 non-null     object
#  3   좌표정보(x)  29 non-null     float64
#  4   좌표정보(y)  29 non-null     float64
#  5   의료기관종별명  29 non-null     object
#  6   진료과목내용   29 non-null     object
#  7   진료과목내용명  29 non-null     object
#  8   주소       29 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 2.3+ KB
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_26780/1441060339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import requests

# %%
searching = '제주특별자치도 제주시 아란13길 15'
url = 'http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
url
# Out:
# 'http://dapi.kakao.com/v2/local/search/keyword.json?query=제주특별자치도 제주시 아란13길 15'

# %%
def find_places(searching):
    url = 'http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
    headers = {
    "Authorization": "KakaoAK b37533f330aa94672bfb49ee94dc4dbf"
    }
    places = requests.get(url, headers = headers).json()['documents']
    
    place = places[0]
    
    name = place['place_name']
    x = place['x']
    y = place['y']
    
    data = [name, x, y, searching]
    
    return(data)

# %%
len(adress_01)
# Out:
# 29

# %%
from tqdm.notebook import tqdm

# %%
location = []
for i in tqdm(hos_jj['주소']):
    try:
        temp = find_places(i)
        location.append(temp)
        time.sleep(1)
    except:
        pass
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
len(location)
# Out:
# 29

# %%
hos_jj_location = pd.DataFrame(location)
hos_jj_location.columns = ['이름', '경도', '위도', '주소']
hos_jj_location.head()
# Out:
#         이름                  경도                  위도                       주소
# 0    제주의료원    126.560876848817    33.4449665714381    제주특별자치도 제주시 산천단남길 10
# 1  서귀포열린병원    126.565429388722    33.2544567337417  제주특별자치도 서귀포시 일주동로 8638
# 2     탑동병원    126.522204298356    33.5176147513627      제주특별자치도 제주시 탑동로 26
# 3   제주우리병원  126.53966603008392  33.488988594791294     제주특별자치도 제주시 중앙로 373
# 4   지오요양병원  126.52025426794067   33.49960785734367     제주특별자치도 제주시 서광로 222

# %%
hos_jj_location.to_excel('./data/hos_jj_location.xlsx', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_26780/2098975321.py in <module>
# ----> 1 hos_jj_location.to_excel('./data/hos_jj_location.xlsx', index = False)
#
# NameError: name 'hos_jj_location' is not defined

# %%
hos_location_df = pd.read_excel('./data/hos_jj_location.xlsx')
hos_location_df.head()
hos_location_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      29 non-null     object
#  1   경도      29 non-null     float64
#  2   위도      29 non-null     float64
#  3   주소      29 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.0+ KB

# %%
import folium
import json

# %%
from folium.plugins import MarkerCluster

# %%
tiles = ['stamenwatercolor', 'cartodbpositron', 
         'openstreetmap', 'stamenterrain']

hos_map = folium.Map(location = [33.36313444555781, 126.52890896316089],
                    tiles = 'StamenTerrain',
                    zoom_start = 11)

for idx in hos_location_df.index:
    
    lat = hos_location_df.loc[idx, '위도']
    lng = hos_location_df.loc[idx, '경도']
    names = hos_location_df.loc[idx, '이름']
    address = '<pre>'+ hos_location_df.loc[idx, '주소'] +'</pre>'
    
    folium.CircleMarker(
    location = [lat, lng],
    popup = address,
    tooltip = names,
    radius = 4,
    weight = 1,
    fill_color = 'y',
    fill_opacity = 0.5).add_to(hos_map)
    
hos_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
locations = []
names = []

for i in range(len(hos_location_df)):
    data = hos_location_df.iloc[i]
    locations.append([data['위도'], data['경도']])
    names.append(data['이름'])
    
# locations
# names

mmm = [33.36313444555781, 126.52890896316089]
map_hos = folium.Map(location = mmm, zoom_start = 10)


tiles = ['stamenwatercolor', 'cartodbpositron', 
         'Stamen Toner', 'stamenterrain']

for tile in tiles:
    folium.TileLayer(tile).add_to(map_hos)
    
marker_cluster = MarkerCluster(locations = locations,
                              popup = names,
                              name = 'hos',
                              overlay = True,
                              control = True).add_to(map_hos)

folium.LayerControl().add_to(map_hos)

map_hos
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
locations = []
names = []

for i in hos_location_df.index:
    data = hos_location_df.iloc[i]
    locations.append([data['위도'], data['경도']])
    names.append(data['이름'])
    
# locations
# names
folium.Marker(location = mmm,
             popup = names,
             tooltip = '혼네',
             icon = folium.Icon(color = 'red',
                               icon_color = 'white',
                               icon = 'angellist',
                               prefix = 'fa' )).add_to(hos_map)


mmm = [33.36313444555781, 126.52890896316089]
map_hos = folium.Map(location = mmm, zoom_start = 10)


tiles = ['stamenwatercolor', 'cartodbpositron', 
         'Stamen Toner', 'stamenterrain']

for tile in tiles:
    folium.TileLayer(tile).add_to(map_hos)
    
marker_cluster = MarkerCluster(locations = locations,
                              popup = names,
                              name = 'hos',
                              overlay = True,
                              tooltip = data['이름'],
                              control = True).add_to(map_hos)

folium.LayerControl().add_to(map_hos)

map_hos
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_20524/314398804.py in <module>
#       6     names = hos_location_df.loc[idx, '이름']
#       7     locations.append([data['위도'], data['경도']])
# ----> 8     names.append(data['이름'])
#       9
#      10 # locations
#
# AttributeError: 'str' object has no attribute 'append'

# %%
latitude = 37.503575
longitude = 127.0498189

m = folium.Map(location = [latitude, longitude],
              width = 600,
              high = 300,
              zoom_start = 15)

folium.Marker(location = [latitude, longitude],
             popup = '<iframe width="700" height="300" src="https://www.youtube.com/embed/NmeaLvaU77Q" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>',
             tooltip = '혼네',
             icon = folium.Icon(color = 'red',
                               icon_color = 'white',
                               icon = 'angellist',
                               prefix = 'fa' )).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
